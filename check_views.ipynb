# %%
import ingestor, viewer

# %%
# %matplotlib notebook

# %%
context = ingestor.Context('runs/generic_immune_useful.run')

# %%
plotter = viewer.View(context)
plotter()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import fitter

# %%
solution = fitter.FitReader('out/out.file')
