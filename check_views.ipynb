# %%
import ingestor, viewer

# %%
# %matplotlib notebook

# %%
context_sv = ingestor.Context('runs/augmented_immune_sv.run')
context_ns = ingestor.Context('runs/augmented_immune_ns.run')

# %%
plotter_sv = viewer.DataPlotter(context_sv)
plotter_sv()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plotter_ns = viewer.DataPlotter(context_ns)
plotter_ns()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import fitter

# %%
#solution = fitter.FitReader('out/out.file')
